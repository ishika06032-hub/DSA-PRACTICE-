# %% [markdown]
# <a href="https://colab.research.google.com/github/ishika06032-hub/DSA-PRACTICE-/blob/main/Copy_of__linear_search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
arr =[10,20,30,40,50 ]
target = 30

for i in range(len(arr)):
    if arr[i] == target:
          print(i)
          break
# Out:
# 2
